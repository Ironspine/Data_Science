# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 200)

# %%
data = pd.read_excel('Data_Oct_2020.xlsx')

# %%
Sub_189 = data[(data['Visa Type'] == '189PTS Points-Tested Stream') & (data['EOI Status'] == 'SUBMITTED')]
Sub_189 = Sub_189.reset_index(drop=True)
Inv_189 = data[(data['Visa Type'] == '189PTS Points-Tested Stream') & (data['EOI Status'] == 'INVITED')]
Inv_189 = Inv_189.reset_index(drop=True)

Sub_190 = data[(data['Visa Type'] == '190SAS Skilled Australian Sponsored') & (data['EOI Status'] == 'SUBMITTED')]
Sub_190 = Sub_190.reset_index(drop=True)
Inv_190 = data[(data['Visa Type'] == '190SAS Skilled Australian Sponsored') & (data['EOI Status'] == 'INVITED')]
Inv_190 = Inv_190.reset_index(drop=True)

Sub_491_Family = data[(data['Visa Type'] == '491FSR Family Sponsored - Regional') & (data['EOI Status'] == 'SUBMITTED')]
Sub_491_Family = Sub_491_Family.reset_index(drop=True)
Inv_491_Family = data[(data['Visa Type'] == '491FSR Family Sponsored - Regional') & (data['EOI Status'] == 'INVITED')]
Inv_491_Family = Inv_491_Family.reset_index(drop=True)

Sub_491_State = data[(data['Visa Type'] == '491SNR State or Territory Nominated - Regional') & (data['EOI Status'] == 'SUBMITTED')]
Sub_491_State = Sub_491_State.reset_index(drop=True)
Inv_491_State = data[(data['Visa Type'] == '491SNR State or Territory Nominated - Regional') & (data['EOI Status'] == 'INVITED')]
Inv_491_State = Inv_491_State.reset_index(drop=True)

# %%
Sub_189
# Out:
#      As At Month                    Visa Type  \
# 0     2020-10-31  189PTS Points-Tested Stream
# 1     2020-10-31  189PTS Points-Tested Stream
# 2     2020-10-31  189PTS Points-Tested Stream
# 3     2020-10-31  189PTS Points-Tested Stream
# 4     2020-10-31  189PTS Points-Tested Stream
# ...          ...                          ...
# 1500  2020-10-31  189PTS Points-Tested Stream
# 1501  2020-10-31  189PTS Points-Tested Stream
# 1502  2020-10-31  189PTS Points-Tested Stream
# 1503  2020-10-31  189PTS Points-Tested Stream
# 1504  2020-10-31  189PTS Points-Tested Stream
#
#                                Occupation EOI Status  Points Count EOIs
# 0     133111 Construction Project Manager  SUBMITTED    40.0        <20
# 1     133111 Construction Project Manager  SUBMITTED    45.0        <20
# 2     133111 Construction Project Manager  SUBMITTED    50.0        <20
# 3     133111 Construction Project Manager  SUBMITTED    55.0        <20
# ...

# %%
df = pd.read_excel('SkillSelect_Sample.xlsx', index_col=0)
df['ANZSCO'] = df['ANZSCO'].astype('str')
df
# Out:
#       Unit group      ANZSCO Occupations & Sub-specialisations  \
# 0            1111  111111 Chief Executive or Managing Director
# 1            1111                      Chief Executive Officer
# 2            1111                             Director-General
# 3            1111                           Executive Director
# 4            1111      Secretary (Government Department) (Aus)
# ...           ...                                          ...
# 3199         8999                                         Grip
# 3200         8999                 Racecourse Barrier Attendant
# 3201         8999                                    Stagehand
# 3202         8999                                  Studio Hand
# 3203         8999                  Swimming Pool Serviceperson
#
#                    Occupation description & skill level  \
# 0     CHIEF EXECUTIVES AND MANAGING DIRECTORS determ...
# 1                                                   NaN
# ...

# %%
# POINTS

print('189 Submitted')
for num in range(65, 140, 5):
    EOI = Sub_189[Sub_189['Points'] == int(num)]
    for row in range(len(EOI)):
        if EOI['Occupation'].iloc[row].split()[0] in list(df['ANZSCO']):
            for index in df[df['ANZSCO'] == EOI['Occupation'].iloc[row].split()[0]].index:
                df['189 - EOI Sub ' + str(num) + ' Points'].iloc[index] = EOI['Count EOIs'].iloc[row]
    print(df['189 - EOI Sub ' + str(num) + ' Points'].isnull().sum())
print('')

print('189 Invited')
for num in range(65, 140, 5):
    EOI = Inv_189[Inv_189['Points'] == int(num)]
    for row in range(len(EOI)):
        if EOI['Occupation'].iloc[row].split()[0] in list(df['ANZSCO']):
            for index in df[df['ANZSCO'] == EOI['Occupation'].iloc[row].split()[0]].index:
                df['189 - Invited ' + str(num) + ' Points'].iloc[index] = EOI['Count EOIs'].iloc[row]
    print(df['189 - Invited ' + str(num) + ' Points'].isnull().sum())
print('')

print('190 Submitted')
for num in range(65, 130, 5):
    EOI = Sub_190[Sub_190['Points'] == int(num)]
    for row in range(len(EOI)):
        if EOI['Occupation'].iloc[row].split()[0] in list(df['ANZSCO']):
            for index in df[df['ANZSCO'] == EOI['Occupation'].iloc[row].split()[0]].index:
                df['190 - EOI Sub ' + str(num) + ' Points'].iloc[index] = EOI['Count EOIs'].iloc[row]
    print(df['190 - EOI Sub ' + str(num) + ' Points'].isnull().sum())
print('')

print('190 Invited')
for num in range(65, 130, 5):
    EOI = Inv_190[Inv_190['Points'] == int(num)]
    for row in range(len(EOI)):
        if EOI['Occupation'].iloc[row].split()[0] in list(df['ANZSCO']):
            for index in df[df['ANZSCO'] == EOI['Occupation'].iloc[row].split()[0]].index:
                df['190 - Invited ' + str(num) + ' Points'].iloc[index] = EOI['Count EOIs'].iloc[row]
    print(df['190 - Invited ' + str(num) + ' Points'].isnull().sum())
print('')

print('491 Submitted')
for num in range(65, 140, 5):
    EOI = Sub_491_State[Sub_491_State['Points'] == int(num)]
    for row in range(len(EOI)):
        if EOI['Occupation'].iloc[row].split()[0] in list(df['ANZSCO']):
            for index in df[df['ANZSCO'] == EOI['Occupation'].iloc[row].split()[0]].index:
                df['491 - EOI Sub ' + str(num) + ' Points'].iloc[index] = EOI['Count EOIs'].iloc[row]
    print(df['491 - EOI Sub ' + str(num) + ' Points'].isnull().sum())
print('')

print('491 Invited')
for num in range(65, 140, 5):
    EOI = Inv_491_State[Inv_491_State['Points'] == int(num)]
    for row in range(len(EOI)):
        if EOI['Occupation'].iloc[row].split()[0] in list(df['ANZSCO']):
            for index in df[df['ANZSCO'] == EOI['Occupation'].iloc[row].split()[0]].index:
                df['491 - Invited ' + str(num) + ' Points'].iloc[index] = EOI['Count EOIs'].iloc[row]
    print(df['491 - Invited ' + str(num) + ' Points'].isnull().sum())
print('')

print('491FS Submitted')
for num in range(65, 125, 5):
    EOI = Sub_491_Family[Sub_491_Family['Points'] == int(num)]
    for row in range(len(EOI)):
        if EOI['Occupation'].iloc[row].split()[0] in list(df['ANZSCO']):
            for index in df[df['ANZSCO'] == EOI['Occupation'].iloc[row].split()[0]].index:
                df['491FS - EOI Sub ' + str(num) + ' Points'].iloc[index] = EOI['Count EOIs'].iloc[row]
    print(df['491FS - EOI Sub ' + str(num) + ' Points'].isnull().sum())
print('')

print('491FS Invited')
for num in range(65, 125, 5):
    EOI = Inv_491_Family[Inv_491_Family['Points'] == int(num)]
    for row in range(len(EOI)):
        if EOI['Occupation'].iloc[row].split()[0] in list(df['ANZSCO']):
            for index in df[df['ANZSCO'] == EOI['Occupation'].iloc[row].split()[0]].index:
                df['491FS - Invited ' + str(num) + ' Points'].iloc[index] = EOI['Count EOIs'].iloc[row]
    print(df['491FS - Invited ' + str(num) + ' Points'].isnull().sum())
# Out:
# 189 Submitted
# C:\Users\User\Anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# 2692
# 2695
# 2680
# 2717
# 2747
# 2802
# 2983
# 3087
# 3137
# 3164
# 3187
# 3190
# 3204
# 3204
# 3204
#
# 189 Invited
# 3107
# 3105
# 3074
# 3087
# 3088
# 3137
# 3174
# 3195
# 3200
# 3204
# 3204
# 3204
# 3204
# 3204
# 3204
#
# 190 Submitted
# 2202
# 2179
# 2194
# 2258
# 2341
# 2452
# 2643
# 2872
# 3098
# 3152
# 3169
# 3188
# 3190
#
# 190 Invited
# 3097
# 3057
# 3024
# 3009
# 3038
# 3052
# 3118
# 3166
# 3190
# 3200
# 3204
# 3204
# 3204
#
# 491 Submitted
# 2348
# 2153
# 2114
# 2170
# 2194
# 2273
# 2452
# 2619
# 2826
# 3027
# 3138
# 3171
# 3171
# 3192
# 3190
#
# 491 Invited
# 3160
# 3139
# 3108
# 3086
# 3094
# 3118
# 3126
# ...

# %%
# 189 Sub - EOI Total
for row in range(len(df)):
    total = 0
    for element in df.iloc[row, 16:31]:
        if str(element) != 'nan':
            try:
                total += int(element)
            except:
                total += int(element[1:]) # avoid '<' sign
    df.iloc[row, 31] = total

# 189 Inv - EOI Total
for row in range(len(df)):
    total = 0
    for element in df.iloc[row, 32:47]:
        if str(element) != 'nan':
            try:
                total += int(element)
            except:
                total += int(element[1:]) # avoid '<' sign
    df.iloc[row, 47] = total


# 190 Sub - EOI Total
for row in range(len(df)):
    total = 0
    for element in df.iloc[row, 48:61]:
        if str(element) != 'nan':
            try:
                total += int(element)
            except:
                total += int(element[1:]) # avoid '<' sign
    df.iloc[row, 61] = total

# 190 Inv - EOI Total
for row in range(len(df)):
    total = 0
    for element in df.iloc[row, 62:75]:
        if str(element) != 'nan':
            try:
                total += int(element)
            except:
                total += int(element[1:]) # avoid '<' sign
    df.iloc[row, 75] = total


# 491 Sub - EOI Total
for row in range(len(df)):
    total = 0
    for element in df.iloc[row, 76:91]:
        if str(element) != 'nan':
            try:
                total += int(element)
            except:
                total += int(element[1:]) # avoid '<' sign
    df.iloc[row, 91] = total

# 491 Inv - EOI Total
for row in range(len(df)):
    total = 0
    for element in df.iloc[row, 92:107]:
        if str(element) != 'nan':
            try:
                total += int(element)
            except:
                total += int(element[1:]) # avoid '<' sign
    df.iloc[row, 107] = total


# 491FS Sub - EOI Total
for row in range(len(df)):
    total = 0
    for element in df.iloc[row, 108:120]:
        if str(element) != 'nan':
            try:
                total += int(element)
            except:
                total += int(element[1:]) # avoid '<' sign
    df.iloc[row, 120] = total

# 491FS Inv - EOI Total
for row in range(len(df)):
    total = 0
    for element in df.iloc[row, 121:133]:
        if str(element) != 'nan':
            try:
                total += int(element)
            except:
                total += int(element[1:]) # avoid '<' sign
    df.iloc[row, 133] = total

df['189 - EOI Total'] = df['189 - EOI Total'].astype('int')
df['190 - EOI Total'] = df['190 - EOI Total'].astype('int')
df['491 - EOI Total'] = df['491 - EOI Total'].astype('int')
df['491FS - EOI Total'] = df['491FS - EOI Total'].astype('int')

df['189 - Invited Total'] = df['189 - Invited Total'].astype('int')
df['190 - Invited Total'] = df['190 - Invited Total'].astype('int')
df['491 - Invited Total'] = df['491 - Invited Total'].astype('int')
df['491FS - Invited Total'] = df['491FS - Invited Total'].astype('int')

# %%
for index in range(len(df)):
    if df['ANZSCO Occupations & Sub-specialisations'][index][:6].isnumeric():
        df['ANZSCO Occupations & Sub-specialisations'][index] = df['ANZSCO Occupations & Sub-specialisations'][index][6:]

df.insert(1, 'ANZSCO2', df['ANZSCO'])
df = df.drop(['ANZSCO'], axis=1)
df.rename(columns={'ANZSCO2': 'ANZSCO'}, inplace=True)

anzsco = []
for index in range(len(df)):
    if df['ANZSCO'][index] not in anzsco:
        anzsco.append(df['ANZSCO'][index])
    else:
        df['ANZSCO'][index] = ''
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df
# Out:
#       Unit group   ANZSCO ANZSCO Occupations & Sub-specialisations  \
# 0            1111  111111     Chief Executive or Managing Director
# 1            1111                          Chief Executive Officer
# 2            1111                                 Director-General
# 3            1111                               Executive Director
# 4            1111          Secretary (Government Department) (Aus)
# ...           ...     ...                                      ...
# 3199         8999                                             Grip
# 3200         8999                     Racecourse Barrier Attendant
# 3201         8999                                        Stagehand
# 3202         8999                                      Studio Hand
# 3203         8999                      Swimming Pool Serviceperson
#
#                    Occupation description & skill level  \
# 0     CHIEF EXECUTIVES AND MANAGING DIRECTORS determ...
# ...

# %%
df.to_excel('SkillSelect Oct 2020.xlsx')
